# %%
import requests
import json
import prettytable

# %%
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['LASST320000000000003', 'LASST060000000000003'],"startyear":"2018", "endyear":"2020"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)

# %%
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 135,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'LASST320000000000003',
#     'data': [{'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'latest': 'true',
#       'value': '15.0',
#       'footnotes': [{'code': 'P', 'text': 'Preliminary.'}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '25.3',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '30.1',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '6.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '3.6',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '3.7',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '3.7',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '3.7',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '3.7',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '3.8',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.0',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.0',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.1',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.1',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '4.4',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '4.4',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '4.4',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.5',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.6',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.6',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.7',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.7',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]}]},
#    {'seriesID': 'LASST060000000000003',
#     'data': [{'year': '2020',
#       'period': 'M06',
#       'periodName': 'June',
#       'latest': 'true',
#       'value': '14.9',
#       'footnotes': [{'code': 'P', 'text': 'Preliminary.'}]},
#      {'year': '2020',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '16.4',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '16.4',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '5.5',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '3.9',
#       'footnotes': [{}]},
#      {'year': '2020',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '3.9',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '3.9',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '4.0',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '4.0',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.1',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2019',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '4.2',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '4.3',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]},
#      {'year': '2018',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '4.4',
#       'footnotes': [{'code': 'R',
#         'text': 'Data were subject to revision on March 4, 2020.'}]}]}]}}

# %%
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes = item['footnotes']
       
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()

# %%
json_data

# %%
# Setup
import pandas as pd
import numpy as np
import json
from pprint import pprint
import requests

# Upload CSV file
initial_jobless_claims = "Data/initial_jobless_claims.csv"

# %%
#import the .csv file as a dataframe
initial_jobless_claims_df = pd.read_csv(initial_jobless_claims, encoding="utf-8")

#reset index to be based on State
i_j_c=initial_jobless_claims_df.set_index("State")
i_j_c
# Out:
#                 7/31/2020  7/24/2020  7/17/2020  7/10/2020  7/3/2020  \
# State
# Alabama             11148      17437      23676      20563     19056
# Alaska               5407       6069       6606       9572      6124
# Arizona             16351      19063      21441      28695     25774
# Arkansas            12267      15257      15932      14155     10832
# California         228530     244653     289594     284914    264791
# Colorado             7037       8037       8531      10554      7928
# Connecticut         10572      11181      11667       9955     12267
# Delaware             1998       2563       2720       3167      2791
# Florida             73955      91462     108976     132831     66941
# Georgia(S)          72695      84984     122313     138452    105160
# Hawaii               5195       5885       7581       7668      7648
# Idaho                3402       4703       5687       5458      4924
# ...

# %%
# Example of pulling a few states associated with one date
example_state=i_j_c.loc[['Alaska', "Alabama"],['7/31/2020']]
example_state
# Out:
#          7/31/2020
# State
# Alaska        5407
# Alabama      11148
